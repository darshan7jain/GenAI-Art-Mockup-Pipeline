# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.memeraki.com/collections/mata-ni-pachedi?sort_by=best-selling'

page = requests.get(url)

soup = BeautifulSoup(page.text, 'html')

# %%
lnk=soup.find('ul',id='id="c-accordion--1603134-1"')

# %%
ol_data=soup.find('ol',id='main-collection-product-grid')

# %%
li_items = ol_data.find_all('li')[:10]

# %%
#Single artwork

for item in li_items:
    product_name = item.get('data-alpha')
    size = "N/A"
    details_div = item.find('div', style=lambda val: val and 'justify-content: space-between' in val)
    if details_div:
        p_tags = details_div.find_all('p')
        if len(p_tags) >= 2:
            size = p_tags[1].get_text(strip=True)

    price_tag = item.find('dl', class_='price__regular')
    price = price_tag.get_text(strip=True) if price_tag else "N/A"

    print(f"Product Name: {product_name}")
    print(f"Size: {size}")
    print(f"Price: {price}")
    print("---")
# Out:
# Product Name: Gopashtami in Pichwai by Dinesh Soni
# Size: 60 in X 36 in
# Price: Regular₹150,000
# ---
# Product Name: Sharad Poornima (merged with Daan Leela and Annakoot) in Pichwai by Shehzaad Ali Sherani
# Size: 72 in X 60 in
# Price: RegularRequest Price
# ---
# Product Name: Daan Leela interwined with Shrinathji Darshan in Pichwai by Shehzaad Ali Sherani
# Size: 60 in X 72 in
# Price: Regular₹135,000
# ---
# Product Name: Divine Jubilation: Shehzaad Ali’s tapestry of celebration
# Size: 36 in X 36 in
# Price: Regular₹50,000
# ---
# Product Name: Harmony of Hearts: Melody of Devotion Pichwai by Shehzaad ali Sherani
# Size: 60 in X 48 in
# Price: Regular₹80,000
# ---
# Product Name: Lotus Serenade: Motherhood's Melody in Blue Hues Pichwai By Shehzaad Ali Sherni
# Size: 36 in X 24 in
# Price: Regular₹20,000
# ---
# Product Name: Pichwai Cows under a Banyan tree in Pichwai by Shehzaad Ali Sherani
# Size: 36 in X 36 in
# Price: Regular₹25,000
# ---
# Product Name: Lord Krishna in Pichwai by Shehzaad Ali Sherani
# Size: 36 in X 48 in
# Price: Regular₹80,000
# ---
# Product Name: Sandhya Aarti with Yamuna Ji: Shreenath ji's Pichwai by Shehzaad Ali Sherani
# Size: 36 in X 48 in
# Price: Regular₹60,000
# ---
# Product Name: Radha Krishna's Eternal Love in Pichwai by Shehzaad Ali Sherani
# Size: 36 in X 24 in
# Price: Regular₹30,000
# ---

# %%
artnames=['madhubani','kalamkari','pichwai','gond-art','kalighat','bengal-pattachitra','miniature-paintings','mata-ni-pachedi','warli-paintings','blue-pottery','phad','kerala-mural','tanjore','lippan-kaam']

# %%
#Final list of all artworks
art_data_dict = {}

for artname in artnames:
    url = f'https://www.memeraki.com/collections/{artname}?sort_by=best-selling'
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html')
    
    ol_data = soup.find('ol', id='main-collection-product-grid')
    if not ol_data:
        art_data_dict[artname] = []
        continue
    
    li_items = ol_data.find_all('li')[:10]
    data = []
    
    for item in li_items:
        product_name = item.get('data-alpha')
        size = "N/A"
        details_div = item.find('div', style=lambda val: val and 'justify-content: space-between' in val)
        if details_div:
            p_tags = details_div.find_all('p')
            if len(p_tags) >= 2:
                size = p_tags[1].get_text(strip=True)
        price_tag = item.find('dl', class_='price__regular')
        price = price_tag.get_text(strip=True) if price_tag else "N/A"
        data.append({
            'Product Name': product_name,
            'Size': size,
            'Price': price
        })
    art_data_dict[artname] = data

# print(art_data_dict)
import pprint
pprint.pprint(art_data_dict)
# Out:
# {'bengal-pattachitra': [{'Price': 'Regular₹999',
#                          'Product Name': 'BENGAL PATTACHITRA MASTERCLASS (ON '
#                                          'DEMAND, PRE-RECORDED, SELF PACED)',
#                          'Size': 'N/A'},
#                         {'Price': 'Regular₹6,500',
#                          'Product Name': "Love's Thrilling Ride: A Kalighat "
#                                          'Portrait by Uttam Chitrakar',
#                          'Size': '22 in X 14 in'},
#                         {'Price': 'Regular₹4,000',
#                          'Product Name': 'The reader, Kalighat Art by Bapi '
#                                          'Chitrakar',
#                          'Size': '11.69 in X 8.27 in'},
#                         {'Price': 'Regular₹1,400',
#                          'Product Name': 'Maa Saraswati with a Swan in Bengal '
#                                          'Pattachitra by Manoranjan Chitrakar',
#                          'Size': '11 in X 7 in'},
#                         {'Price': 'Regular₹1,500',
#                          'Product Name': 'Depiction of Maa Durga in Bengal '
#                                          'Pattachitra by Manoranjan Chitrakar',
#                          'Size': '11 in X 7 in'},
#                         {'Price': 'Regular₹4,000',
#                          'Product Name': 'Graceful Charm: Kalighat Art by Bapi '
#                                          'Chitrakar',
#                          'Size': '11.69 in X 8.27 in'},
#                         {'Price': 'Regular₹600',
#                          'Product Name': 'Pleasing appearance of fishes in '
#                                          'Bengal Pattachitra by Manoranjan '
#                                          'Chitrakar',
#                          'Size': '3.5 in X 3.5 in'},
#                         {'Price': 'Regular₹3,500',
#                          'Product Name': 'Maa Saraswati with her Veena Bengal '
#                                          'pattachitra Plate by Manoranjan '
#                                          'Chitrakar',
#                          'Size': '10 in X 10 in'},
#                         {'Price': 'Regular₹4,000',
#                          'Product Name': 'Shared Beauty:Kalighat Art by Bapi '
#                                          'Chitrakar',
#                          'Size': '11.8 in X 9.1 in'},
#                         {'Price': 'Regular₹4,000',
#                          'Product Name': 'Treats of Trust: Kalighat Art by '
#                                          'Bapi Chitrakar',
#                          'Size': '11.69 in X 8.27 in'}],
#  'blue-pottery': [{'Price': 'Regular₹150',
#                    'Product Name': 'Incense Stand, Blue Pottery (blue and '
#                                    'yellow)',
#                    'Size': 'N/A'},
#                   {'Price': 'Regular₹1,300',
#                    'Product Name': 'Lush Green Florals by Vikram Singh Kharol '
#                                    'in Blue Pottery',
#                    'Size': '8 in X 8 in'},
#                   {'Price': 'Regular₹700',
#                    'Product Name': 'Floral Pattern in Blue Pottery Plates by '
#                                    'Gopal Lal Kharol',
#                    'Size': '8 in X 8 in'},
#                   {'Price': 'Regular₹700',
#                    'Product Name': 'A Cow on a plate In Blue Pottery plates by '
#                                    'Gopal Lal Kharol',
#                    'Size': '8 in X 8 in'},
#                   {'Price': 'Regular₹24,000',
#                    'Product Name': 'Pale pink petals In Blue Pottery Plate by '
#                                    'Gopal Saini',
#                    'Size': '10 in X 10 in'},
#                   {'Price': 'Regular₹38,000',
#                    'Product Name': 'Petal like design In Blue Pottery Plate by '
#                                    'Gopal Saini',
#                    'Size': '10 in X 10 in'},
#                   {'Price': 'Regular₹38,000',
#                    'Product Name': 'Floral pattern In Blue Pottery Plate by '
#                                    'Gopal Saini',
#                    'Size': '10 in X 10 in'},
#                   {'Price': 'Regular₹24,000',
#                    'Product Name': 'White Pink Lotus In Blue Pottery Plate by '
#                                    'Gopal Saini',
#                    'Size': '10 in X 10 in'},
#                   {'Price': 'Regular₹30,000',
#                    'Product Name': 'Full Bloom Lotus In Blue Pottery Plate by '
#                                    'Gopal Saini',
#                    'Size': '10 in X 10 in'},
#                   {'Price': 'Regular₹34,000',
#                    'Product Name': 'The Horse In Blue Pottery Plate by Gopal '
#                                    'Saini',
#                    'Size': '10 in X 10 in'}],
#  'gond-art': [{'Price': 'Regular₹999',
#                'Product Name': 'GOND MASTERCLASS (ON-DEMAND, PRE-RECORDED, '
#                                'SELF PACED)',
#                'Size': 'N/A'},
#               {'Price': 'Regular₹1,500',
#                'Product Name': 'Marine Elegance: Gond Art Visions by Kailash '
#                                'Pradhan',
#                'Size': '7 in X 7 in'},
#               {'Price': 'Regular₹1,500',
#                'Product Name': 'Harmony in Diversity: Gond Art Expressions by '
#                                'Kailash Pradhan',
#                'Size': '7 in X 7 in'},
#               {'Price': 'Regular₹1,500',
#                'Product Name': 'Bound by Nature: Gond Art Musings by Kailash '
#                                'Pradhan',
#                'Size': '7 in X 7 in'},
#               {'Price': 'Regular₹1,500',
#                'Product Name': 'Symphony of Plumage: Gond Art Interactions by '
#                                'Kailash Pradhan',
#                'Size': '7 in X 7 in'},
#               {'Price': 'RegularRequest Price',
#                'Product Name': 'Hanuman’s Valour: Gond Painting by Venkat '
#                                'Shyam',
#                'Size': '30 in X 22 in'},
#               {'Price': 'Regular₹400',
#                'Product Name': 'Turtle in Gond by Kailash Pradhan',
#                'Size': '4 in X 4 in'},
#               {'Price': 'Regular₹1,500',
#                'Product Name': 'Turtles in Gond art by Kailash Pradhan',
#                'Size': '8 in X 6 in'},
#               {'Price': 'Regular₹400',
#                'Product Name': 'Azure Majesty: The Serene Blue Elephant of '
#                                'Gond Art Gond Painting by Kailash Pradhan',
#                'Size': '4 in X 4 in'},
#               {'Price': 'Regular₹1,500',
#                'Product Name': 'Tales on Tusk and Feather: Gond Art Sagas by '
#                                'Kailash Pradhan',
#                'Size': '7 in X 7 in'}],
#  'kalamkari': [{'Price': 'Regular₹999',
#                 'Product Name': 'KALAMKARI MASTERCLASS (ON DEMAND, '
#                                 'PRE-RECORDED, SELF PACED)',
#                 'Size': 'N/A'},
#                {'Price': 'Regular₹20,000',
#                 'Product Name': 'The Sacred Grove: Nurturing Blessings: '
#                                 'Kalamkari Painting by Harinath.N',
#                 'Size': '12 in X 12 in'},
#                {'Price': 'Regular₹12,000',
#                 'Product Name': 'Tree of Life Kalamkari Painting by Siva Reddy',
#                 'Size': '28 in X 21 in'},
#                {'Price': 'Regular₹5,000',
#                 'Product Name': 'A Woman At Door in Kalamkari by K. '
#                                 'Lakshminarayanan',
#                 'Size': '23 in X 19 in'},
#                {'Price': 'Regular₹3,200',
#                 'Product Name': 'Mata Saraswati Kalamkari Painting by Siva '
#                                 'Reddy',
#                 'Size': '15 in X 11 in'},
#                {'Price': 'Regular₹4,500',
#                 'Product Name': 'Maa Saraswati Kalamkari Painting by Siva '
#                                 'Reddy',
#                 'Size': '14 in X 14 in'},
#                {'Price': 'Regular₹3,200',
#                 'Product Name': 'Krishna with Cows Kalamkari Painting by Siva '
#                                 'Reddy',
#                 'Size': '10 in X 16 in'},
#                {'Price': 'Regular₹96,000',
#                 'Product Name': 'Tree of Life: Kalamkari painting by '
#                                 'Harinath.N',
#                 'Size': '48 in X 72 in'},
#                {'Price': 'Regular₹30,000',
#                 'Product Name': 'Tree of Life: Kalamkari painting by Sudheer',
#                 'Size': '57.1 in X 34.3 in'},
#                {'Price': 'Regular₹70,000',
#                 'Product Name': 'Dancing Krishna With Cows : Kalamkari '
#                                 'painting by Harinath.N',
#                 'Size': '62 in X 40 in'}],
#  'kalighat': [{'Price': 'Regular₹999',
#                'Product Name': 'KALIGHAT MASTERCLASS (ON DEMAND, PRE-RECORDED, '
#                                'SELF PACED)',
#                'Size': 'N/A'},
#               {'Price': 'Regular₹6,500',
#                'Product Name': "Love's Thrilling Ride: A Kalighat Portrait by "
#                                'Uttam Chitrakar',
#                'Size': '22 in X 14 in'},
#               {'Price': 'Regular₹4,000',
#                'Product Name': 'The reader, Kalighat Art by Bapi Chitrakar',
#                'Size': '11.69 in X 8.27 in'},
#               {'Price': 'Regular₹3,200',
#                'Product Name': 'Whispers of Romance: Uttam Chitrakar’s '
#                                'Kalighat Love Tale',
#                'Size': '14 in X 11 in'},
#               {'Price': 'Regular₹3,200',
#                'Product Name': "Mirror of Confidence: Uttam Chitrakar's "
#                                'Kalighat Self-Admiration',
#                'Size': '14 in X 11 in'},
#               {'Price': 'Regular₹4,000',
#                'Product Name': 'Graceful Charm: Kalighat Art by Bapi Chitrakar',
#                'Size': '11.69 in X 8.27 in'},
#               {'Price': 'Regular₹5,000',
#                'Product Name': 'The Musical Cat in Kalighat by Sonali '
#                                'Chitrakar',
#                'Size': '14 in X 11 in'},
#               {'Price': 'Regular₹3,000',
#                'Product Name': 'Working Women In Kalighat by Uttam Chitrakar',
#                'Size': '11 in X 8.5 in'},
#               {'Price': 'Regular₹5,000',
#                'Product Name': 'Human & Technology in Kalighat by Uttam '
#                                'Chitrakar',
#                'Size': '14 in X 11 in'},
#               {'Price': 'Regular₹6,500',
#                'Product Name': "Mystical Sojourn: Uttam Chitrakar's Celestial "
#                                'Kalighat',
#                'Size': '24 in X 15 in'}],
#  'kerala-mural': [{'Price': 'Regular₹8,500',
#                    'Product Name': 'The Banyan Tree in Kerala Mural by Adarsh',
#                    'Size': '18 in X 12 in'},
#                   {'Price': 'Regular₹80,000',
#                    'Product Name': 'The Ananthashayanam: A Kerala Mural Marvel '
#                                    'by Adarsh',
#                    'Size': '37 in X 61 in'},
#                   {'Price': 'Regular₹30,000',
#                    'Product Name': 'Submerged Symphony: Unveiling an Aquatic '
#                                    'Utopia, Kerala Mural by Adarsh',
#                    'Size': '37 in X 22.5 in'},
#                   {'Price': 'Regular₹90,000',
#                    'Product Name': 'Ananthashayanam Kerala Mural Painting by '
#                                    'Adarsh',
#                    'Size': '36 in X 76 in'},
#                   {'Price': 'Regular₹56,250',
#                    'Product Name': 'The Majestic Buddha In Kerala Mural by '
#                                    'Adarsh',
#                    'Size': '36 in X 30 in'},
#                   {'Price': 'Regular₹30,000',
#                    'Product Name': 'Peacock In Kerala Mural by Adarsh',
#                    'Size': '37 in X 16 in'},
#                   {'Price': 'Regular₹28,000',
#                    'Product Name': 'Ganesha in Kerala Mural by Adarsh',
#                    'Size': '24 in X 24 in'},
#                   {'Price': 'Regular₹49,200',
#                    'Product Name': 'Lord Ganesha In Kerala Mural by Adarsh',
#                    'Size': '36.5 in X 31 in'},
#                   {'Price': 'Regular₹36,000',
#                    'Product Name': 'Krishna and Kuchela In Kerala Mural By '
#                                    'Jijulal',
#                    'Size': '36 in X 24 in'},
#                   {'Price': 'Regular₹25,500',
#                    'Product Name': 'Tree of Life in Kerala Mural by Adarsh',
#                    'Size': '18 in X 12 in'}],
#  'lippan-kaam': [{'Price': 'Regular₹999',
#                   'Product Name': 'LIPPAN MASTERCLASS (ON DEMAND, '
#                                   'PRE-RECORDED, SELF PACED)',
#                   'Size': 'N/A'},
#                  {'Price': 'Regular₹1,350',
#                   'Product Name': 'Lippan Mudwork Art Kit (11*11 inch board)',
#                   'Size': 'N/A'},
#                  {'Price': 'Regular₹1,950',
#                   'Product Name': 'Lippan Mudwork Art Kit (15 * 24 inch board)',
#                   'Size': 'N/A'},
#                  {'Price': 'Regular₹2,500',
#                   'Product Name': 'Wall Panel in Lippan by Nalemitha',
#                   'Size': '12 in X 12 in'},
#                  {'Price': 'Regular₹2,500',
#                   'Product Name': 'Mirror work on Mud Tile in Lippan by '
#                                   'Nalemitha',
#                   'Size': '12 in X 12 in'},
#                  {'Price': 'Regular₹800',
#                   'Product Name': 'Kutch Embroidery and Lippan Wall Panel by '
#                                   'Nalemitha',
#                   'Size': '7 in X 7 in'},
#                  {'Price': 'Regular₹2,000',
#                   'Product Name': 'Elegancy of Blossoms: Lippan Kaam Artwork '
#                                   'by Nalemitha',
#                   'Size': '12 in X 12 in'},
#                  {'Price': 'Regular₹3,000',
#                   'Product Name': 'Ethereal Reflections in Lippan/ Mudwork by '
#                                   'Hafiz Mutva',
#                   'Size': '12 in X 12 in'},
#                  {'Price': 'Regular₹2,500',
#                   'Product Name': 'Wall Panel in Lippan by Nalemitha',
#                   'Size': '12 in X 12 in'},
#                  {'Price': 'RegularRequest Price',
#                   'Product Name': 'Bronze Mirror work Lippan Kaam by Nalemitha',
#                   'Size': '24 in X 24 in'}],
#  'madhubani': [{'Price': 'Regular₹1,250',
#                 'Product Name': 'Madhubani Traditional Art Kit for Madhubani '
#                                 'Masterclass',
#                 'Size': 'N/A'},
#                {'Price': 'Regular₹1,750',
#                 'Product Name': 'A STROLL THROUGH THE SPOKEN FOREST,CREAM SILK '
#                                 'CLUTCH',
#                 'Size': 'N/A'},
#                {'Price': 'Regular₹800',
#                 'Product Name': 'Madhubani Patterns in rust and black , '
#                                 'Madhubani handpainted coasters',
#                 'Size': 'N/A'},
#                {'Price': 'Regular₹800',
#                 'Product Name': 'Madhubani Patterns , Madhubani handpainted '
#                                 'coasters',
#                 'Size': 'N/A'},
#                {'Price': 'Regular₹800',
#                 'Product Name': 'Patterns in black and blue, Madhubani '
#                                 'handpainted coasters',
#                 'Size': 'N/A'},
#                {'Price': 'Regular₹1,200',
#                 'Product Name': 'Divine illumination besides charm and '
#                                 'essence: Madhubani Plate by Priti Karn',
#                 'Size': 'N/A'},
#                {'Price': 'Regular₹3,749',
#                 'Product Name': 'A stroll through the spoken forest, Maroon '
#                                 'Vegan Laptop Bag/Tote',
#                 'Size': 'N/A'},
#                {'Price': 'Regular₹5,100',
#                 'Product Name': 'Madhubani Painting of Good Luck Charm by '
#                                 'Ambika Devi',
#                 'Size': '7.5 in X 22 in'},
#                {'Price': 'Regular₹1,749',
#                 'Product Name': 'A STROLL THROUGH THE SPOKEN FOREST,BLACK SILK '
#                                 'CLUTCH',
#                 'Size': 'N/A'},
#                {'Price': 'Regular₹6,000',
#                 'Product Name': 'The Kiss in Madhubani by Izhar Ansari',
#                 'Size': '16.5 in X 11.7 in'}],
#  'mata-ni-pachedi': [{'Price': 'Regular₹28,000',
#                       'Product Name': 'Ambe Mata Mata Ni Pachedi By Dilip '
#                                       'Chitara For Home Decor',
#                       'Size': '24 in X 36 in'},
#                      {'Price': 'Regular₹16,000',
#                       'Product Name': 'Goddess Meldi Mata Ni Pachedi By Dilip '
#                                       'Chitara For Home Decor',
#                       'Size': '25 in X 25 in'},
#                      {'Price': 'Regular₹170,000',
#                       'Product Name': 'Dual Harmony Mata Ni Pachedi By Sanjay '
#                                       'Chitara For Home Decor',
#                       'Size': '48 in X 72 in'},
#                      {'Price': 'Regular₹5,000',
#                       'Product Name': 'Tree Of Life Mata Ni Pachedi By Dilip '
#                                       'Chitara For Home Decor',
#                       'Size': '12 in X 12 in'},
#                      {'Price': 'Regular₹5,000',
#                       'Product Name': 'Tree Of Life Mata Ni Pachedi By Dilip '
#                                       'Chitara For Home Decor',
#                       'Size': '12 in X 12 in'},
#                      {'Price': 'Regular₹70,000',
#                       'Product Name': 'Grace Of Ambe Mata Mata Ni Pachedi By '
#                                       'Sanjay Chitara For Home Decor',
#                       'Size': '48 in X 30 in'},
#                      {'Price': 'Regular₹40,000',
#                       'Product Name': 'Tree Of Life Mata Ni Pachedi By Dilip '
#                                       'Chitara For Home Decor',
#                       'Size': '42 in X 42 in'},
#                      {'Price': 'Regular₹50,000',
#                       'Product Name': 'Life in the Desert in Mata ni Pachedi '
#                                       'by Vasant Manubhai Chitara',
#                       'Size': '24 in X 36 in'},
#                      {'Price': 'Regular₹70,000',
#                       'Product Name': 'The Desert Life in Mata ni Pachedi by '
#                                       'Vasant Manubhai Chitara',
#                       'Size': '36 in X 60 in'},
#                      {'Price': 'Regular₹70,000',
#                       'Product Name': "The Nature's Play in Mata ni Pachedi by "
#                                       'Vasant Manubhai Chitara',
#                       'Size': '36 in X 60 in'}],
#  'miniature-paintings': [{'Price': 'Regular₹999',
#                           'Product Name': 'MUGHAL MINIATURE MASTERCLASS (ON '
#                                           'DEMAND, PRE-RECORDED, SELF PACED)',
#                           'Size': 'N/A'},
#                          {'Price': 'Regular₹1,749',
#                           'Product Name': 'BIRDS OF A FEATHER, BLACK SILK '
#                                           'CLUTCH',
#                           'Size': 'N/A'},
#                          {'Price': 'Regular₹6,999',
#                           'Product Name': 'BIRDS OF A FEATHER',
#                           'Size': 'N/A'},
#                          {'Price': 'Regular₹2,249',
#                           'Product Name': 'Birds of a Feather, Foldover '
#                                           'Clutch/Sling',
#                           'Size': 'N/A'},
#                          {'Price': 'Regular₹1,750',
#                           'Product Name': 'A TALE OF TWO LOVERS, YELLOW CANE '
#                                           'BOX SLING',
#                           'Size': 'N/A'},
#                          {'Price': 'Regular₹3,500',
#                           'Product Name': 'A TALE OF TWO LOVERS, BLUE CANE BOX '
#                                           'SLING',
#                           'Size': 'N/A'},
#                          {'Price': 'Regular₹6,999',
#                           'Product Name': 'WHITE LEAVES',
#                           'Size': 'N/A'},
#                          {'Price': 'Regular₹1,750',
#                           'Product Name': 'NO FINER THINGS THAN DOGS, GREEN '
#                                           'CANE BOX SLING',
#                           'Size': 'N/A'},
#                          {'Price': 'Regular₹700',
#                           'Product Name': 'A Flight into Eternity – The Mughal '
#                                           'Miniature Postcard by Mohan '
#                                           'Prajapati',
#                           'Size': '3.5 in X 5.5 in'},
#                          {'Price': 'Regular₹700',
#                           'Product Name': "Wetland Whispers: A Woodpecker's "
#                                           'portrayal Miniature Painting by '
#                                           'Mohan Prajapati',
#                           'Size': '3.5 in X 5.5 in'}],
#  'phad': [{'Price': 'Regular₹1,300',
#            'Product Name': 'Dance scene along with musical instruments: Phad '
#                            'by Kalyan Joshi',
#            'Size': '10 in X 10 in'},
#           {'Price': 'Regular₹125,000',
#            'Product Name': 'Shree Hanuman Chalisa Phad Painting by Kalyan '
#                            'Joshi',
#            'Size': '48 in X 36 in'},
#           {'Price': 'Regular₹1,500',
#            'Product Name': 'Radiant imagery of couples: Phad by Kalyan Joshi',
#            'Size': '11 in X 9 in'},
#           {'Price': 'Regular₹1,300',
#            'Product Name': 'Lord Krishna playing flute: Phad by Kalyan Joshi',
#            'Size': '10 in X 10 in'},
#           {'Price': 'Regular₹1,300',
#            'Product Name': 'Imagery of couples along with maids: Phad by '
#                            'Kalyan Joshi',
#            'Size': '10 in X 10 in'},
#           {'Price': 'Regular₹6,720',
#            'Product Name': 'Golden Serenity: A Radiant Tree by Kalyan Joshi',
#            'Size': '14.5 in X 11 in'},
#           {'Price': 'Regular₹6,720',
#            'Product Name': 'Wisdom of the Woods: Serenading Deer by Kalyan '
#                            'Joshi',
#            'Size': '14.5 in X 11 in'},
#           {'Price': 'Regular₹1,300',
#            'Product Name': 'Victory of the King: Floral Celebration by Kalyan '
#                            'Joshi',
#            'Size': '10 in X 10 in'},
#           {'Price': 'Regular₹20,200',
#            'Product Name': 'The Birth of Krishna, Phad Painting by Kalyan '
#                            'Joshi',
#            'Size': '13.5 in X 23 in'},
#           {'Price': 'Regular₹51,000',
#            'Product Name': 'Hanuman Chalisa in Phad by Kalyan Joshi',
#            'Size': '22 in X 30 in'}],
#  'pichwai': [{'Price': 'Regular₹999',
#               'Product Name': 'PICHWAI MASTERCLASS (ON-DEMAND, PRE-RECORDED, '
#                               'SELF-PACED)',
#               'Size': 'N/A'},
#              {'Price': 'N/A',
#               'Product Name': 'In-person Pichwai Workshop at Triveni Kala '
#                               'Sangam',
#               'Size': 'N/A'},
#              {'Price': 'N/A',
#               'Product Name': 'In-person Pichwai Workshop',
#               'Size': 'N/A'},
#              {'Price': 'N/A',
#               'Product Name': 'In-person Pichwai Workshop at Triveni Kala '
#                               'Sangam',
#               'Size': 'N/A'},
#              {'Price': 'N/A',
#               'Product Name': 'In-person Pichwai Workshop',
#               'Size': 'N/A'},
#              {'Price': 'N/A',
#               'Product Name': 'In-person Pichwai Workshop at Triveni Kala '
#                               'Sangam',
#               'Size': 'N/A'},
#              {'Price': 'RegularRequest Price',
#               'Product Name': 'Sharad Poornima (merged with Daan Leela and '
#                               'Annakoot) in Pichwai by Shehzaad Ali Sherani',
#               'Size': '72 in X 60 in'},
#              {'Price': 'Regular₹25,000',
#               'Product Name': 'Pichwai Cows under a Banyan tree in Pichwai by '
#                               'Shehzaad Ali Sherani',
#               'Size': '36 in X 36 in'},
#              {'Price': 'Regular₹6,999',
#               'Product Name': 'Pichwai Traditional Art Kit for Pichwai '
#                               'Masterclass (12 natural colour set)',
#               'Size': 'N/A'},
#              {'Price': 'Regular₹40,000',
#               'Product Name': 'Beyond the Blue: Lotus Euphoria Pichwai by '
#                               'Shehzaad Ali Sherni',
#               'Size': '36 in X 36 in'}],
#  'tanjore': [{'Price': 'Regular₹999',
#               'Product Name': 'TANJORE ART MASTERCLASS  (ON-DEMAND, '
#                               'PRE-RECORDED, SELF PACED)',
#               'Size': 'N/A'},
#              {'Price': 'Regularfrom₹325',
#               'Product Name': 'Gold Leaf (22k)',
#               'Size': 'N/A'},
#              {'Price': 'Regular₹6,599',
#               'Product Name': 'Tanjore Art kit for Masterclass (with '
#                               'traditional materials with 22k gold)',
#               'Size': 'N/A'},
#              {'Price': 'Regular₹1,550',
#               'Product Name': 'Handmade Muck-board  - 10 x 12 inches (Tanjore)',
#               'Size': 'N/A'},
#              {'Price': 'Regular₹4,500',
#               'Product Name': 'Tanjore (with traditional materials)',
#               'Size': 'N/A'},
#              {'Price': 'Regular₹1,200',
#               'Product Name': 'Handmade Muck-board  - 8 x 10 inches (Tanjore)',
#               'Size': 'N/A'},
#              {'Price': 'Regular₹2,000',
#               'Product Name': 'Peacock, Tanjore Art by Sanjay Tandekar',
#               'Size': '5 in X 5 in'},
#              {'Price': 'Regular₹44,000',
#               'Product Name': 'Radha krishna in Tanjore by  M. Mahesh',
#               'Size': '20 in X 16 in'},
#              {'Price': 'Regular₹3,600',
#               'Product Name': 'Radha-Krishna, Tanjore Painting by Sanjay '
#                               'Tandekar',
#               'Size': '6 in X 6 in'},
#              {'Price': 'Regular₹100,000',
#               'Product Name': "Raja Rajeswari's Golden abode : Mysore Painting "
#                               'by Dr. J Dundaraja',
#               'Size': '24 in X 18 in'}],
#  'warli-paintings': [{'Price': 'Regular₹999',
#                       'Product Name': 'Warli Painting Masterclass - (On '
#                                       'Demand, Pre-Recorded, Self Paced)',
#                       'Size': 'N/A'},
#                      {'Price': 'Regular₹1,250',
#                       'Product Name': 'Warli Traditional Art Kit for Warli '
#                                       'Masterclass',
#                       'Size': 'N/A'},
#                      {'Price': 'Regular₹3,800',
#                       'Product Name': 'Harmony beneath the Tree of Life: Warli '
#                                       'by Dilip Bahotha',
#                       'Size': '14 in X 14 in'},
#                      {'Price': 'Regular₹3,800',
#                       'Product Name': 'Fishing night in Warli by Dilip Ram '
#                                       'Bahotha',
#                       'Size': '14 in X 14 in'},
#                      {'Price': 'Regular₹1,500',
#                       'Product Name': 'Fisherman in Warli By Dilip Bahotha',
#                       'Size': '10 in X 6 in'},
#                      {'Price': 'Regular₹3,800',
#                       'Product Name': 'The Harmony in Heritage: A Warli Marvel '
#                                       'by Dilip Bahotha',
#                       'Size': '14 in X 14 in'},
#                      {'Price': 'Regular₹1,500',
#                       'Product Name': 'Village Life In Warli By Dilip Bahotha',
#                       'Size': '10 in X 6 in'},
#                      {'Price': 'Regular₹24,000',
#                       'Product Name': 'Serene Forest in Warli by Sayli Prasad '
#                                       'Dadoda',
#                       'Size': '31 in X 22 in'},
#                      {'Price': 'Regular₹3,800',
#                       'Product Name': 'The Tribal Way of Life: Warli by Dilip '
#                                       'Bahotha',
#                       'Size': '14 in X 14 in'},
#                      {'Price': 'Regular₹3,800',
#                       'Product Name': 'A Tapestry of Wonder in Warli by Dilip '
#                                       'Bahotha',
#                       'Size': '14 in X 14 in'}]}
